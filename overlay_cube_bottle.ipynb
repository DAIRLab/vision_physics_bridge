# %%
import numpy as np
import os
import time
from file_utils import load_toss_time_from_yaml

import rosbag
import yaml

import meshcat
import meshcat.geometry as g
import meshcat.transformations as tf

from tempfile import TemporaryDirectory

from PIL import Image
import io
import rospy 
import trimesh
import uuid
from math_utils import rotation_matrix_to_quaternion, transform_bundletrack_output
# video resolution
video_resolution=[640, 480]

#
## parameters:
#
toss_id = 1
cam = 'cam0'
video_name = f'bottle_toss_{toss_id}'
bottle_mesh_file = './assets/bundlesdf_bottle_mesh.obj'
odom_bag_file = './rosbags/odom_43.bag'
cam_bag_file = './rosbags/raw_43.bag'
cam_poses_file = './assets/realsense_pose_bottle.yaml'
output_file = './' + video_name + '.mp4'
start_time = None
end_time = None
yaml_path = './assets/config.yaml'
toss_type = 'bottle'
start_time = load_toss_time_from_yaml(yaml_path, toss_type, toss_id, 'start_time')
end_time = load_toss_time_from_yaml(yaml_path, toss_type, toss_id, 'end_time')

cam_topic = '/camera/color/image_raw'

intrinsics = [380.2484436035156, 379.8265380859375,314.2138977050781, 240.59800720214844,] # fx, fy, cx, cy

with open(cam_poses_file, 'r') as stream:
    data_loaded = yaml.safe_load(stream)
print(data_loaded[cam]['pose']['position']['x'])

cam_pos_dict = data_loaded[cam]['pose']['position']
cam_position = [cam_pos_dict['x'], cam_pos_dict['y'], cam_pos_dict['z']]
cam_rot_dict = data_loaded[cam]['pose']['rotation']
cam_orientation = [cam_rot_dict['x'], cam_rot_dict['y'], cam_rot_dict['z']]

# For extrinsic matrix
cam_trans = np.array([cam_pos_dict['x'], cam_pos_dict['y'], cam_pos_dict['z']]).reshape(-1, 1)
cam_axis_vec = np.array([cam_rot_dict['x'], cam_rot_dict['y'], cam_rot_dict['z']])

# Compute T_WC, transform from world to camera
cam_angle = np.linalg.norm(cam_orientation)
cam_axis = cam_orientation/cam_angle
T_WC = tf.translation_matrix(cam_position) @ tf.quaternion_matrix(tf.quaternion_about_axis(cam_angle, cam_axis))
print(tf.quaternion_matrix(tf.quaternion_about_axis(cam_angle, cam_axis)))

# Given fov_x, fov_y, desire output to be h x w resolution
# set fov=fov_y, screen_h = h
# set screen_w = fov_x/fov_y * w

fx = intrinsics[0]
fy = intrinsics[1]

fov_x = 2*np.arctan(video_resolution[1]/(2*fy))*180/np.pi
fov_y = 2*np.arctan(video_resolution[0]/(2*fx))*180/np.pi


cam_fov = fov_x

print('Extracted field of view: ' + f'{cam_fov:f}')


resolution = video_resolution

vis = meshcat.Visualizer()
# Out:
# 1.21476532
# [[ 0.63554619  0.46097571 -0.61934032  0.        ]
#  [ 0.77204586 -0.37413632  0.51377739  0.        ]
#  [ 0.00512119 -0.8046884  -0.5936753   0.        ]
#  [ 0.          0.          0.          1.        ]]
# Extracted field of view: 64.574913
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7001/static/

# %%
# Create the object. Set the opacity of the "real" to > 0 if you want to see it, for invisible
# meshcat_geom = trimesh.load_mesh(bottle_mesh_file)
meshcat_geom = meshcat.geometry.ObjMeshGeometry.from_file(
            bottle_mesh_file)
meshcat_geom.uuid = str(uuid.uuid5(
                  uuid.NAMESPACE_X500, meshcat_geom.contents))
material = g.MeshLambertMaterial(
                             color=0xffffff,
                             reflectivity=0.0,
                             transparent=0,
                             opacity=.4)
material.uuid = str(uuid.uuid5(
      uuid.NAMESPACE_X500, meshcat_geom.contents
      + "material"))
mesh = meshcat.geometry.Mesh(meshcat_geom, material)
mesh.uuid = str(uuid.uuid5(
      uuid.NAMESPACE_X500, meshcat_geom.contents
      + "mesh"))
# vis['real_1'].set_object(g.MeshGeometry(vertices, faces))
# vis["real_1"].set_object(g.MeshGeometry(mesh.vertices, mesh.faces),
#                        g.MeshLambertMaterial(
#                              color=0x00ff00,
#                              reflectivity=0.0,
#                              transparent=0,
#                              opacity=.4))

# %%
bag = rosbag.Bag(odom_bag_file)

# get summary info from rosbag as a dictionary
info = yaml.load(bag._get_yaml_info(), Loader=yaml.FullLoader)
TOPIC_STRING_1 = '/tagslam/odom/body_bottle'

# extract metadata from cube and board topics
elbow_1_topic = [topic for topic in info['topics'] if topic['topic'] == TOPIC_STRING_1][0]

num_msg = elbow_1_topic['messages']

def extract_times(messages):
    t_ros = np.zeros(len(messages))
    for i, data in enumerate(list(messages)):
        (_, msg, _) = data
        tstamp = msg.header.stamp
        t_ros[i] = tstamp.secs + tstamp.nsecs * 1e-9

    return t_ros


def extract_poses(messages, start_time, end_time):
    # poses = np.zeros((7, len(messages)))
    poses = np.zeros((7,1))
    for i, data in enumerate(messages):
        (_, msg, _) = data
        if start_time <= msg.header.stamp < end_time:
            pose = msg.pose.pose
            pose_pos = np.asarray([pose.position.x, pose.position.y, pose.position.z])
            pose_quat = np.asarray([pose.orientation.w, pose.orientation.x, pose.orientation.y,
                                    pose.orientation.z])
            # print(np.hstack((pose_quat, pose_pos)).T.shape)
            poses = np.hstack((poses, np.hstack((pose_quat, pose_pos)).T.reshape((-1,1))))
            # poses[:4, i] = pose_quat
            # poses[4:7, i] = pose_pos
    return poses[:,1:]

def get_bundletrack_results():
    """
    State vector is 4 quaternion + 3 xyz position + 3 angular velocity + 3 linear velocity.
    """
    frame_num = len([name for name in os.listdir(DATA_DIR)])
    print("%i frames in total!"%frame_num)
    poses = np.zeros((7, frame_num))
    for frame_id in range(1, frame_num+1):
        pose = np.loadtxt(DATA_DIR + "%04i.txt" % frame_id)#in camera frame
        pose = transform_bundletrack_output(
            pose,
            DATA_DIR,
            ODOM_FILE_PATH,
            cam_trans,
            cam_axis_vec
        )
        pose_quat = rotation_matrix_to_quaternion(pose)
        pose_quat = pose_quat.reshape(1, -1)
        pose_pos = np.array(pose[:3, 3])
        poses[:4, frame_id-1] = pose_quat
        poses[4:7, frame_id-1] = pose_pos
    return poses

DATA_DIR = f"/home/cnets-vision/mengti_ws/BundleSDF/results/bottle_toss_{toss_id}/ob_in_cam/"
ODOM_FILE_PATH = f"/home/cnets-vision/mengti_ws/BundleSDF/data/bottle_toss_{toss_id}/annotated_poses/"

bundletrack_poses = get_bundletrack_results()
# t_ros = extract_times(list(bag.read_messages(topics=[TOPIC_STRING_1])))
elbow_1 = extract_poses(list(bag.read_messages(topics=[TOPIC_STRING_1])), start_time, end_time)
# t_ros_2 = extract_times(list(bag.read_messages(topics=[TOPIC_STRING_2])))
# elbow_2 = extract_poses(list(bag.read_messages(topics=[TOPIC_STRING_2])))
print("elbow1: ", elbow_1.shape)
if (bundletrack_poses.shape[1]>elbow_1.shape[1]):
    bundletrack_poses = bundletrack_poses[:, :elbow_1.shape[1]]
print("bundletrack: ", bundletrack_poses.shape)
bag.close()
# Out:
# 180 frames in total!
# elbow1:  (7, 180)
# bundletrack:  (7, 180)

# %%
from cv_bridge import CvBridge

# Load video
raw_bag = rosbag.Bag(cam_bag_file)
cam_messages= list(raw_bag.read_messages(topics=[cam_topic]))

num_cam_msg = len(cam_messages)
# print(num_cam_msg)
# extract camera
t_cam = np.zeros(len(cam_messages))
cam_data = []
bridge = CvBridge()
for i, data in enumerate(cam_messages):
    (_, msg, _) = data
    tstamp = msg.header.stamp
    if start_time <= tstamp < end_time:
        t_cam[i] = tstamp.secs + tstamp.nsecs * 1e-9
        # cam_data.append(msg.data)
        cv_img = bridge.imgmsg_to_cv2(msg, desired_encoding="passthrough")
        cam_data.append(cv_img)
print(len(cam_data))
# Out:
# 180

# %%
base_url = "http://127.0.0.1"

meshcat_url = base_url + ":" + vis.url().split(":")[-1]

''' Create precisely-sized iframe with meshcat view; put this in its own Jupyter cell. '''
from IPython.display import HTML
frame_html = """
<div style="height: {height}px; width: {width}px; overflow-x: visible; overflow-y: visible; resize: none">
    <iframe src="{url}" style="width: 100%; height: 100%; border: none"></iframe>
</div>
""".format(url=meshcat_url, width=resolution[0], height=resolution[1])
HTML(frame_html)
# Out:
# <div style="height: 480px; width: 640px; overflow-x: visible; overflow-y: visible; resize: none">
#     <iframe src="http://127.0.0.1:7000/static/" style="width: 100%; height: 100%; border: none"></iframe>
# </div>

# %%
# Frames
# (W) World
# (M) Meshcat
# (C) Camera
# (A) link_1
# (B) link_2

vis["cam"].set_transform(T_WC)
vis["cam_view"].set_transform(T_WC @ tf.translation_matrix([0,0,.05]))

# T_MC, look along z-axis but rotote by 180 degrees
T_MC = tf.translation_matrix([0, 0, -1]) @ tf.rotation_matrix(np.pi, (0,0,1))

T_MW = T_MC @ tf.inverse_matrix(T_WC)

cam = g.PerspectiveCamera(fov=cam_fov, zoom=1, aspect=640/480)
vis["/Cameras/default/rotated"].set_object(cam)

# vis["/Cameras/default/rotated/<object>"].set_property("zoom", 1)
vis["/Cameras/default/rotated/<object>"].set_property("position", [0,0,0])
vis["/Cameras/default"].set_transform(T_MC)

# %%
# view in meshcat save to images
# Turn off background, axes, and grid.
vis['/Background'].set_property("visible", False)
vis['/Grid'].set_property("visible", False)
vis['/Axes'].set_property("visible", False)

with TemporaryDirectory(prefix="ros-process-") as tmpdir:
    print(tmpdir)
    for i, pose in enumerate(bundletrack_poses.T):
        print('Processing frame ' + f'{i:d}' + ' of ' + f'{bundletrack_poses.shape[1]:d}', end='\r')
        print(i)
        
        im = Image.fromarray(cam_data[i]).convert('RGB')
        T_WA = tf.translation_matrix(pose[4:7]) @ tf.quaternion_matrix(pose[:4])
        vis["real_1"].set_transform(T_MW @ T_WA)

        
        mesh_im = vis.get_image()
        # print(mesh_im.size)
        # mesh_im.show()
        im.paste(mesh_im, (0,0), mask = mesh_im)
        # im.show()
        # break
        im.save(tmpdir + '/' + f'{i:07d}' + '.png', format="png")
    os.system('ffmpeg -y -r 150 -i ' + tmpdir + '/%07d.png -vcodec libx264 -preset slow -crf 18 ' + output_file)
# Out:
# /tmp/ros-process-birfhrek
# 0rocessing frame 0 of 180
# 1rocessing frame 1 of 180
# 2rocessing frame 2 of 180
# 3rocessing frame 3 of 180
# 4rocessing frame 4 of 180
# 5rocessing frame 5 of 180
# 6rocessing frame 6 of 180
# 7rocessing frame 7 of 180
# 8rocessing frame 8 of 180
# 9rocessing frame 9 of 180
# 10ocessing frame 10 of 180
# 11ocessing frame 11 of 180
# 12ocessing frame 12 of 180
# 13ocessing frame 13 of 180
# 14ocessing frame 14 of 180
# 15ocessing frame 15 of 180
# 16ocessing frame 16 of 180
# 17ocessing frame 17 of 180
# 18ocessing frame 18 of 180
# 19ocessing frame 19 of 180
# 20ocessing frame 20 of 180
# 21ocessing frame 21 of 180
# 22ocessing frame 22 of 180
# 23ocessing frame 23 of 180
# 24ocessing frame 24 of 180
# 25ocessing frame 25 of 180
# 26ocessing frame 26 of 180
# 27ocessing frame 27 of 180
# 28ocessing frame 28 of 180
# 29ocessing frame 29 of 180
# 30ocessing frame 30 of 180
# 31ocessing frame 31 of 180
# 32ocessing frame 32 of 180
# 33ocessing frame 33 of 180
# 34ocessing frame 34 of 180
# 35ocessing frame 35 of 180
# 36ocessing frame 36 of 180
# 37ocessing frame 37 of 180
# 38ocessing frame 38 of 180
# 39ocessing frame 39 of 180
# 40ocessing frame 40 of 180
# 41ocessing frame 41 of 180
# 42ocessing frame 42 of 180
# 43ocessing frame 43 of 180
# 44ocessing frame 44 of 180
# 45ocessing frame 45 of 180
# 46ocessing frame 46 of 180
# 47ocessing frame 47 of 180
# 48ocessing frame 48 of 180
# 49ocessing frame 49 of 180
# 50ocessing frame 50 of 180
# 51ocessing frame 51 of 180
# 52ocessing frame 52 of 180
# 53ocessing frame 53 of 180
# 54ocessing frame 54 of 180
# 55ocessing frame 55 of 180
# 56ocessing frame 56 of 180
# 57ocessing frame 57 of 180
# 58ocessing frame 58 of 180
# 59ocessing frame 59 of 180
# 60ocessing frame 60 of 180
# 61ocessing frame 61 of 180
# 62ocessing frame 62 of 180
# 63ocessing frame 63 of 180
# 64ocessing frame 64 of 180
# 65ocessing frame 65 of 180
# 66ocessing frame 66 of 180
# 67ocessing frame 67 of 180
# 68ocessing frame 68 of 180
# 69ocessing frame 69 of 180
# 70ocessing frame 70 of 180
# 71ocessing frame 71 of 180
# 72ocessing frame 72 of 180
# 73ocessing frame 73 of 180
# 74ocessing frame 74 of 180
# 75ocessing frame 75 of 180
# 76ocessing frame 76 of 180
# 77ocessing frame 77 of 180
# 78ocessing frame 78 of 180
# 79ocessing frame 79 of 180
# 80ocessing frame 80 of 180
# 81ocessing frame 81 of 180
# 82ocessing frame 82 of 180
# 83ocessing frame 83 of 180
# 84ocessing frame 84 of 180
# 85ocessing frame 85 of 180
# 86ocessing frame 86 of 180
# 87ocessing frame 87 of 180
# 88ocessing frame 88 of 180
# 89ocessing frame 89 of 180
# 90ocessing frame 90 of 180
# 91ocessing frame 91 of 180
# 92ocessing frame 92 of 180
# 93ocessing frame 93 of 180
# 94ocessing frame 94 of 180
# 95ocessing frame 95 of 180
# 96ocessing frame 96 of 180
# 97ocessing frame 97 of 180
# 98ocessing frame 98 of 180
# 99ocessing frame 99 of 180
# 100cessing frame 100 of 180
# 101cessing frame 101 of 180
# 102cessing frame 102 of 180
# 103cessing frame 103 of 180
# 104cessing frame 104 of 180
# 105cessing frame 105 of 180
# 106cessing frame 106 of 180
# 107cessing frame 107 of 180
# 108cessing frame 108 of 180
# 109cessing frame 109 of 180
# 110cessing frame 110 of 180
# 111cessing frame 111 of 180
# 112cessing frame 112 of 180
# 113cessing frame 113 of 180
# 114cessing frame 114 of 180
# 115cessing frame 115 of 180
# 116cessing frame 116 of 180
# 117cessing frame 117 of 180
# 118cessing frame 118 of 180
# 119cessing frame 119 of 180
# 120cessing frame 120 of 180
# 121cessing frame 121 of 180
# 122cessing frame 122 of 180
# 123cessing frame 123 of 180
# 124cessing frame 124 of 180
# 125cessing frame 125 of 180
# 126cessing frame 126 of 180
# 127cessing frame 127 of 180
# 128cessing frame 128 of 180
# 129cessing frame 129 of 180
# 130cessing frame 130 of 180
# 131cessing frame 131 of 180
# 132cessing frame 132 of 180
# 133cessing frame 133 of 180
# 134cessing frame 134 of 180
# 135cessing frame 135 of 180
# 136cessing frame 136 of 180
# 137cessing frame 137 of 180
# 138cessing frame 138 of 180
# 139cessing frame 139 of 180
# 140cessing frame 140 of 180
# 141cessing frame 141 of 180
# 142cessing frame 142 of 180
# 143cessing frame 143 of 180
# 144cessing frame 144 of 180
# 145cessing frame 145 of 180
# 146cessing frame 146 of 180
# 147cessing frame 147 of 180
# 148cessing frame 148 of 180
# 149cessing frame 149 of 180
# 150cessing frame 150 of 180
# 151cessing frame 151 of 180
# 152cessing frame 152 of 180
# 153cessing frame 153 of 180
# 154cessing frame 154 of 180
# 155cessing frame 155 of 180
# 156cessing frame 156 of 180
# 157cessing frame 157 of 180
# 158cessing frame 158 of 180
# 159cessing frame 159 of 180
# 160cessing frame 160 of 180
# 161cessing frame 161 of 180
# 162cessing frame 162 of 180
# 163cessing frame 163 of 180
# 164cessing frame 164 of 180
# 165cessing frame 165 of 180
# 166cessing frame 166 of 180
# 167cessing frame 167 of 180
# 168cessing frame 168 of 180
# 169cessing frame 169 of 180
# 170cessing frame 170 of 180
# 171cessing frame 171 of 180
# 172cessing frame 172 of 180
# 173cessing frame 173 of 180
# 174cessing frame 174 of 180
# 175cessing frame 175 of 180
# 176cessing frame 176 of 180
# 177cessing frame 177 of 180
# 178cessing frame 178 of 180
# 179cessing frame 179 of 180
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/tmp/ros-process-birfhrek/%07d.png':
#   Duration: 00:00:07.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562a8a3c0c40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562a8a3c0c40] profile High 4:4:4 Predictive, level 3.2, 4:4:4 8-bit
# [libx264 @ 0x562a8a3c0c40] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './bottle_toss_1.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 640x480, q=-1--1, 150 fps, 19200 tbn, 150 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  185 fps=173 q=-1.0 Lsize=     377kB time=00:00:01.21 bitrate=2546.5kbits/s dup=5 drop=0 speed=1.14x
# video:374kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.797275%
# [libx264 @ 0x562a8a3c0c40] frame I:1     Avg QP:20.49  size: 35970
# [libx264 @ 0x562a8a3c0c40] frame P:46    Avg QP:22.67  size:  5558
# [libx264 @ 0x562a8a3c0c40] frame B:138   Avg QP:28.18  size:   658
# [libx264 @ 0x562a8a3c0c40] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x562a8a3c0c40] mb I  I16..4: 16.3%  0.0% 83.7%
# [libx264 @ 0x562a8a3c0c40] mb P  I16..4:  1.0%  0.0%  2.3%  P16..4: 58.9% 13.0%  7.9%  0.0%  0.0%    skip:17.0%
# [libx264 @ 0x562a8a3c0c40] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 25.3%  1.7%  0.5%  direct: 0.6%  skip:71.8%  L0:35.3% L1:59.9% BI: 4.8%
# [libx264 @ 0x562a8a3c0c40] direct mvs  spatial:94.2% temporal:5.8%
# [libx264 @ 0x562a8a3c0c40] coded y,u,v intra: 72.8% 36.7% 22.6% inter: 5.5% 3.5% 1.0%
# [libx264 @ 0x562a8a3c0c40] i16 v,h,dc,p:  8% 11% 14% 67%
# [libx264 @ 0x562a8a3c0c40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  4%  3%  4% 14% 18% 12% 17% 13% 16%
# [libx264 @ 0x562a8a3c0c40] Weighted P-Frames: Y:6.5% UV:0.0%
# [libx264 @ 0x562a8a3c0c40] ref P L0: 46.6%  8.9% 27.1%  6.9% 10.2%  0.3%
# [libx264 @ 0x562a8a3c0c40] ref B L0: 85.3% 11.6%  2.6%  0.5%
# [libx264 @ 0x562a8a3c0c40] ref B L1: 91.5%  8.5%
# [libx264 @ 0x562a8a3c0c40] kb/s:2481.02
