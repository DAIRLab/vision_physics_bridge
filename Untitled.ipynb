# %%
# %pip install ipympl
# Out:
# ...
#   Using cached ipympl-0.9.1-py2.py3-none-any.whl (508 kB)
# ...
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# creating 3d plot using matplotlib 
# in python
  
# for creating a responsive plot
# %matplotlib widget
  
# importing required libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
  
# creating random dataset
xs = [1.1416436, 1.1416436, -0.337, -0.337, 1.1416436, 1.1416436, -0.337, -0.337]
ys = [-0.45649999999999996, 0.45649999999999996, -0.45649999999999996, 0.45649999999999996, -0.45649999999999996, 0.45649999999999996, -0.45649999999999996, 0.45649999999999996]
zs = [-0.268, -0.268, -0.268, -0.268, -0.278, -0.278, -0.278, -0.278]
# creating figure
fig = plt.figure()
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection="3d")

# creating the plot
plot_geeks = ax.scatter(xs, ys, zs, color='green')
  
# setting title and labels
ax.set_title("3D plot")
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
  
# displaying the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
